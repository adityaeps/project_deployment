# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
train = pd.read_csv('Dataset\\train.csv')

# %%
train
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1        2       0  79.33  Central  78.33   Others   Science     77.48
# 2        3       0  65.00  Central  68.00  Central      Arts     64.00
# 3        4       0  56.00  Central  52.00  Central   Science     52.00
# 4        5       0  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...     ...    ...      ...    ...      ...       ...       ...
# 210    211       0  80.60   Others  82.00   Others  Commerce     77.60
# 211    212       0  58.00   Others  60.00   Others   Science     72.00
# 212    213       0  67.00   Others  67.00   Others  Commerce     73.00
# 213    214       1  74.00   Others  66.00   Others  Commerce     58.00
# 214    215       0  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
train.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
train.describe()
# Out:
#             sl_no      gender       ssc_p       hsc_p    degree_p     etest_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000    0.353488   67.303395   66.333163   66.370186   72.100558
# std     62.209324    0.479168   10.827205   10.897509    7.358743   13.275956
# min      1.000000    0.000000   40.890000   37.000000   50.000000   50.000000
# 25%     54.500000    0.000000   60.600000   60.900000   61.000000   60.000000
# 50%    108.000000    0.000000   67.000000   65.000000   66.000000   71.000000
# 75%    161.500000    1.000000   75.700000   73.000000   72.000000   83.500000
# max    215.000000    1.000000   89.400000   97.700000   91.000000   98.000000
#
#             mba_p         salary
# count  215.000000     148.000000
# mean    62.278186  288655.405405
# std      5.833385   93457.452420
# min     51.210000  200000.000000
# 25%     57.945000  240000.000000
# 50%     62.000000  265000.000000
# 75%     66.255000  300000.000000
# max     77.890000  940000.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    int64
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(2), object(7)
# memory usage: 25.3+ KB

# %%
train.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
train['status'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
train.corr()
# Out:
#              sl_no    gender     ssc_p     hsc_p  degree_p   etest_p  \
# sl_no     1.000000 -0.074306 -0.078155 -0.085711 -0.088281  0.063636
# gender   -0.074306  1.000000  0.068969  0.021334  0.173217 -0.084294
# ssc_p    -0.078155  0.068969  1.000000  0.511472  0.538404  0.261993
# hsc_p    -0.085711  0.021334  0.511472  1.000000  0.434206  0.245113
# degree_p -0.088281  0.173217  0.538404  0.434206  1.000000  0.224470
# etest_p   0.063636 -0.084294  0.261993  0.245113  0.224470  1.000000
# mba_p     0.022327  0.300531  0.388478  0.354823  0.402364  0.218055
# salary    0.063764 -0.158912  0.035330  0.076819 -0.019272  0.178307
#
#              mba_p    salary
# sl_no     0.022327  0.063764
# gender    0.300531 -0.158912
# ssc_p     0.388478  0.035330
# hsc_p     0.354823  0.076819
# degree_p  0.402364 -0.019272
# etest_p   0.218055  0.178307
# mba_p     1.000000  0.175013
# salary    0.175013  1.000000

# %%
sns.heatmap(train.corr(),cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
categorical_column = []
for i in train.columns:
    if train[i].dtype == 'O':
        categorical_column.append(i)
print(categorical_column)
# Out:
# ['ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
conda install -c conda-forge dtale
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\hp\anaconda3
#
#   added / updated specs:
#     - dtale
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.0.9        |   py39h415ef7b_7         334 KB  conda-forge
#     dash-2.7.0                 |     pyhd8ed1ab_0         7.8 MB  conda-forge
#     dash-bootstrap-components-1.2.1|     pyhd8ed1ab_0         111 KB  conda-forge
#     dash-core-components-2.0.0 |     pyhd8ed1ab_1           7 KB  conda-forge
#     dash-daq-0.5.0             |     pyh9f0ad1d_1         545 KB  conda-forge
#     dash-html-components-2.0.0 |     pyhd8ed1ab_1           8 KB  conda-forge
#     dash_colorscales-0.0.4     |     pyh9f0ad1d_0          59 KB  conda-forge
#     dtale-2.9.0                |     pyhd8ed1ab_0        10.4 MB  conda-forge
#     flask-compress-1.13        |     pyhd8ed1ab_0          15 KB  conda-forge
#     lz4-3.1.3                  |   py39h2bbff1b_0          96 KB
#     missingno-0.4.2            |             py_1          12 KB  conda-forge
#     squarify-0.4.3             |             py_0           7 KB  conda-forge
#     strsimpy-0.1.9             |     pyh9f0ad1d_0          22 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        19.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      conda-forge/win-64::brotli-python-1.0.9-py39h415ef7b_7 None
#   dash               conda-forge/noarch::dash-2.7.0-pyhd8ed1ab_0 None
#   dash-bootstrap-co~ conda-forge/noarch::dash-bootstrap-components-1.2.1-pyhd8ed1ab_0 None
#   dash-core-compone~ conda-forge/noarch::dash-core-components-2.0.0-pyhd8ed1ab_1 None
#   dash-daq           conda-forge/noarch::dash-daq-0.5.0-pyh9f0ad1d_1 None
#   dash-html-compone~ conda-forge/noarch::dash-html-components-2.0.0-pyhd8ed1ab_1 None
#   dash_colorscales   conda-forge/noarch::dash_colorscales-0.0.4-pyh9f0ad1d_0 None
# Note: you may need to restart the kernel to use updated packages.
#
#   dtale              conda-forge/noarch::dtale-2.9.0-pyhd8ed1ab_0 None
#   flask-compress     conda-forge/noarch::flask-compress-1.13-pyhd8ed1ab_0 None
#   lz4                pkgs/main/win-64::lz4-3.1.3-py39h2bbff1b_0 None
#   missingno          conda-forge/noarch::missingno-0.4.2-py_1 None
#   squarify           conda-forge/noarch::squarify-0.4.3-py_0 None
#   strsimpy           conda-forge/noarch::strsimpy-0.1.9-pyh9f0ad1d_0 None
#
#
#
# Downloading and Extracting Packages
#
# brotli-python-1.0.9  | 334 KB    |            |   0%
# brotli-python-1.0.9  | 334 KB    | 4          |   5%
# brotli-python-1.0.9  | 334 KB    | ###8       |  38%
# brotli-python-1.0.9  | 334 KB    | ######2    |  62%
# brotli-python-1.0.9  | 334 KB    | ########## | 100%
# brotli-python-1.0.9  | 334 KB    | ########## | 100%
#
# missingno-0.4.2      | 12 KB     |            |   0%
# missingno-0.4.2      | 12 KB     | ########## | 100%
# missingno-0.4.2      | 12 KB     | ########## | 100%
#
# dash-html-components | 8 KB      |            |   0%
# dash-html-components | 8 KB      | ########## | 100%
# dash-html-components | 8 KB      | ########## | 100%
#
# lz4-3.1.3            | 96 KB     |            |   0%
# lz4-3.1.3            | 96 KB     | #6         |  17%
# lz4-3.1.3            | 96 KB     | ########## | 100%
# lz4-3.1.3            | 96 KB     | ########## | 100%
#
# dash-bootstrap-compo | 111 KB    |            |   0%
# dash-bootstrap-compo | 111 KB    | #4         |  14%
# dash-bootstrap-compo | 111 KB    | ########## | 100%
# dash-bootstrap-compo | 111 KB    | ########## | 100%
#
# dash-core-components | 7 KB      |            |   0%
# dash-core-components | 7 KB      | ########## | 100%
# dash-core-components | 7 KB      | ########## | 100%
#
# dash_colorscales-0.0 | 59 KB     |            |   0%
# dash_colorscales-0.0 | 59 KB     | ##7        |  27%
# dash_colorscales-0.0 | 59 KB     | ########## | 100%
# dash_colorscales-0.0 | 59 KB     | ########## | 100%
#
# squarify-0.4.3       | 7 KB      |            |   0%
# squarify-0.4.3       | 7 KB      | ########## | 100%
# squarify-0.4.3       | 7 KB      | ########## | 100%
#
# dash-2.7.0           | 7.8 MB    |            |   0%
# dash-2.7.0           | 7.8 MB    |            |   0%
# dash-2.7.0           | 7.8 MB    | 5          |   5%
# dash-2.7.0           | 7.8 MB    | #2         |  13%
# dash-2.7.0           | 7.8 MB    | #7         |  18%
# dash-2.7.0           | 7.8 MB    | ##2        |  23%
# dash-2.7.0           | 7.8 MB    | ##7        |  28%
# dash-2.7.0           | 7.8 MB    | ###2       |  33%
# dash-2.7.0           | 7.8 MB    | ###6       |  37%
# dash-2.7.0           | 7.8 MB    | ####       |  41%
# dash-2.7.0           | 7.8 MB    | ####5      |  46%
# dash-2.7.0           | 7.8 MB    | #####      |  51%
# dash-2.7.0           | 7.8 MB    | #####5     |  55%
# dash-2.7.0           | 7.8 MB    | ######     |  60%
# dash-2.7.0           | 7.8 MB    | ######5    |  65%
# dash-2.7.0           | 7.8 MB    | ######9    |  70%
# dash-2.7.0           | 7.8 MB    | #######3   |  74%
# dash-2.7.0           | 7.8 MB    | #######7   |  78%
# dash-2.7.0           | 7.8 MB    | ########1  |  82%
# dash-2.7.0           | 7.8 MB    | ########6  |  86%
# dash-2.7.0           | 7.8 MB    | #########1 |  91%
# dash-2.7.0           | 7.8 MB    | #########6 |  96%
# dash-2.7.0           | 7.8 MB    | ########## | 100%
#
# flask-compress-1.13  | 15 KB     |            |   0%
# flask-compress-1.13  | 15 KB     | ########## | 100%
# flask-compress-1.13  | 15 KB     | ########## | 100%
#
# strsimpy-0.1.9       | 22 KB     |            |   0%
# strsimpy-0.1.9       | 22 KB     | #######3   |  73%
# strsimpy-0.1.9       | 22 KB     | ########## | 100%
#
# dtale-2.9.0          | 10.4 MB   |            |   0%
# dtale-2.9.0          | 10.4 MB   |            |   0%
# dtale-2.9.0          | 10.4 MB   | 2          |   3%
# dtale-2.9.0          | 10.4 MB   | 4          |   4%
# dtale-2.9.0          | 10.4 MB   | 5          |   5%
# dtale-2.9.0          | 10.4 MB   | 6          |   6%
# dtale-2.9.0          | 10.4 MB   | 6          |   7%
# dtale-2.9.0          | 10.4 MB   | 9          |   9%
# dtale-2.9.0          | 10.4 MB   | #          |  11%
# dtale-2.9.0          | 10.4 MB   | #6         |  16%
# dtale-2.9.0          | 10.4 MB   | ##1        |  21%
# dtale-2.9.0          | 10.4 MB   | ##5        |  25%
# dtale-2.9.0          | 10.4 MB   | ##8        |  29%
# dtale-2.9.0          | 10.4 MB   | ###2       |  33%
# dtale-2.9.0          | 10.4 MB   | ###6       |  36%
# dtale-2.9.0          | 10.4 MB   | ###9       |  40%
# dtale-2.9.0          | 10.4 MB   | ####3      |  43%
# dtale-2.9.0          | 10.4 MB   | ####7      |  47%
# dtale-2.9.0          | 10.4 MB   | #####      |  51%
# dtale-2.9.0          | 10.4 MB   | #####4     |  55%
# dtale-2.9.0          | 10.4 MB   | #####8     |  58%
# dtale-2.9.0          | 10.4 MB   | ######1    |  62%
# dtale-2.9.0          | 10.4 MB   | ######5    |  66%
# dtale-2.9.0          | 10.4 MB   | ######9    |  69%
# dtale-2.9.0          | 10.4 MB   | #######2   |  73%
# dtale-2.9.0          | 10.4 MB   | #######6   |  76%
# dtale-2.9.0          | 10.4 MB   | #######8   |  79%
# dtale-2.9.0          | 10.4 MB   | ########1  |  82%
# dtale-2.9.0          | 10.4 MB   | ########4  |  85%
# dtale-2.9.0          | 10.4 MB   | ########8  |  89%
# dtale-2.9.0          | 10.4 MB   | #########3 |  93%
# dtale-2.9.0          | 10.4 MB   | #########6 |  97%
# dtale-2.9.0          | 10.4 MB   | ########## | 100%
#
# dash-daq-0.5.0       | 545 KB    |            |   0%
# dash-daq-0.5.0       | 545 KB    | 2          |   3%
# dash-daq-0.5.0       | 545 KB    | ########## | 100%
# dash-daq-0.5.0       | 545 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
import dtale

# %%
dtale.show(train)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-180GJPA:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2022-11-16 19:18:46,169 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.
# 2022-11-16 19:18:46,249 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.
# 2022-11-16 19:18:46,281 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.
# 2022-11-16 19:18:52,498 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.
# 2022-11-16 19:18:55,562 - WARNING  - findfont: Font family ['Heiti TC'] not found. Falling back to DejaVu Sans.
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\hp\anaconda3\lib\site-packages\dtale\views.py:2791: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
